# %% [markdown]
# ###
#
# PyGithub: https://github.com/PyGithub/PyGithub
# Download Large file ref: https://github.com/PyGithub/PyGithub/issues/661

# %%
from github import Github, GithubException
import os
import base64

# %%
parent_dir = "./github_backup"

# First create a Github instance:

# using an access token
ACCESS_TOKEN="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"
g = Github(ACCESS_TOKEN)

# %%
def get_content_file(repo, repo_filepath):
    repo_dir = repo.name
    repo_subdir = repo_filepath.split(repo_filepath.split('/')[-1])[0]
    filename = repo_filepath.split('/')[-1]
    print('repo_dir = [{}]'.format(repo_dir))
    print('repo_subdir = [{}]'.format(repo_subdir))
    print('filename = [{}]'.format(filename))
    
    contents = blob = None
    try:
        contents = repo.get_contents(repo_filepath)
    except GithubException:
        blob = repo.get_git_blob(file_content.sha)
    
    local_path = '{}/{}/{}'.format(parent_dir, repo_dir, repo_subdir)
    print('Create folder: [{}]'.format(local_path))
    if not os.path.exists(local_path):
        os.makedirs(local_path)
    with open(local_path + '/' + filename, 'wb') as f:
        if contents != None:
            f.write(base64.b64decode(contents.content))
        else:
            b64 = base64.b64decode(blob.content)
            #b64.decode("utf8")
            f.write(b64)

# %%
# Then play with your Github objects:
for repo in g.get_user().get_repos():
    print('===== Repo: {} ====='.format(repo.name))
    
    if repo.name != 'smartbi.ai-customer-claire':
        continue
    
    contents = repo.get_contents("")

    while contents:
        file_content = contents.pop(0)
        if file_content.type == "dir":
            contents.extend(repo.get_contents(file_content.path))
        else:
            print(file_content)
            get_content_file(repo, file_content.path)
            
            #break
# Out:
# ===== Repo: ai-clipboard =====
# ===== Repo: arxivscraper =====
# ===== Repo: assistant-mfun =====
# ===== Repo: assistant-qna =====
# ===== Repo: assistant-suni =====
# ===== Repo: autoencoder =====
# ===== Repo: awesome-2vec =====
# ===== Repo: azure-services =====
# ===== Repo: ChineseNLPCorpus =====
# ===== Repo: dash_on_flask =====
# ===== Repo: data-scientist-tools =====
# ===== Repo: dialogflow-accuweatheragent =====
# ===== Repo: dialogflow-firebasetest =====
# ===== Repo: documents =====
# ===== Repo: fb_spider =====
# ===== Repo: flask-session =====
# ===== Repo: Flask-User =====
# ===== Repo: Flask-User-starter-app =====
# ===== Repo: gensen-font =====
# ===== Repo: HanLP =====
# ===== Repo: har-keras-cnn =====
# ===== Repo: heroku-ai-service =====
# ===== Repo: heroku-retail =====
# ===== Repo: ImageData =====
# ===== Repo: kg =====
# ===== Repo: labelImg =====
# ===== Repo: lightfm =====
# ===== Repo: line-bot-test-0518 =====
# ===== Repo: Mask_RCNN_simon =====
# ...
